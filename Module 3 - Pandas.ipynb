# %% [markdown]
# # 3.1 Introduction to Pandas
#
# **Pandas** is a powerful Python library used to store, manipulate, and analyze **tabular data** using a **DataFrame**.
#
# ---
#
# ### What is a DataFrame?
#
# A **DataFrame** is a **2D labeled data structure**, similar to a table in a database or an Excel sheet.
#
# - It consists of **rows and columns**
# - Each row is identified by an **index**
# - Each column has a **column label (name)**
#
# ---
#
# ### Key Features of a DataFrame
#
# - Stores data in **tabular (row–column) format**
# - Supports **heterogeneous data** (each column can have a different data type)
# - Easy data selection, filtering, and manipulation
# - Built-in support for handling missing data
#
# ---
#
# ### Structure of a DataFrame
#
# | Index | Column 1 | Column 2 | Column 3 |
# |------|----------|----------|----------|
# | 0    | Data     | Data     | Data     |
# | 1    | Data     | Data     | Data     |
#
# ---
#
# ### Important Points
#
# - Pandas DataFrames are **mutable**
# - Each column can contain **different types of values**
# - Widely used in **data analysis and data science**

# %% [markdown]
# # 3.2 Working with Pandas DataFrame
#  ### Key Points
#  - `head()` and `tail()` are used to preview data
#  - shape gives rows and columns count
#  - columns returns column labels
#  - DataFrame supports easy filtering and selection

# %%
import pandas as pd

# %% [markdown]
#  ### 1. Creating a DataFrame from List

# %%
std_data = [
    [1, 'Varun', 30, 'Male', 'Chandigarh'],
    [2, 'Aman', 25, 'Male', 'Delhi']
]

df = pd.DataFrame(
    std_data,
    columns=['stu_id', 'name', 'age', 'gender', 'city']
)

# %% [markdown]
#  ### 2. From Dictionary

# %%
data = {
    "Name": ["Amit", "Riya"],
    "Score": [185, 927]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Score
# 0  Amit    185
# 1  Riya    927

# %% [markdown]
#  ### 3. From Numpy Arrays

# %%
import numpy as np

arr = np.array([
    [10, 20],
    [30, 40]
])

df = pd.DataFrame(arr, columns=["X", "Y"])
print(df)
# Out:
#     X   Y
# 0  10  20
# 1  30  40

# %% [markdown]
#  ### 4. Viewing Data

# %%
df = pd.read_csv(
    "Data/sales_data_sample.csv",
    encoding="latin1"
)

df.head()        # By default shows top 5 rows
df.head(2)       # Shows top 2 rows

df.tail()        # By default shows bottom 5 rows
df.tail(2)       # Shows bottom 2 rows
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2821  3/28/2005  Shipped       1         3     2005  ...
# 2822   5/6/2005  On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE COUNTRY  \
# 2821  1 rue Alsace-Lorraine           NaN  Toulouse   NaN      31000  France
# 2822     8616 Spinnaker Dr.           NaN    Boston    MA      51003     USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2821      EMEA          Roulet          Annette    Small
# 2822       NaN         Yoshido             Juri   Medium
#
# [2 rows x 25 columns]

# %% [markdown]
#  ### 5. Shape of DataFrame

# %%
df.shape         # (number_of_rows, number_of_columns)
# Out:
# (2823, 25)

# %% [markdown]
#  ### 6. Column Names

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
#  ### 7. Accessing Columns

# %%
df['STATUS']        # Access single column
df.STATUS           # Another way to access column
# Out:
# 0        Shipped
# 1        Shipped
# 2        Shipped
# 3        Shipped
# 4        Shipped
#           ...
# 2818     Shipped
# 2819     Shipped
# 2820    Resolved
# 2821     Shipped
# 2822     On Hold
# Name: STATUS, Length: 2823, dtype: object

# %% [markdown]
#  ### 8. Accessing Multiple Columns

# %%
df[['CONTACTFIRSTNAME', 'CONTACTLASTNAME']]
# Out:
#      CONTACTFIRSTNAME CONTACTLASTNAME
# 0                Kwai              Yu
# 1                Paul         Henriot
# 2              Daniel        Da Cunha
# 3               Julie           Young
# 4               Julie           Brown
# ...               ...             ...
# 2818            Diego          Freyre
# 2819           Pirkko       Koskitalo
# 2820            Diego          Freyre
# 2821          Annette          Roulet
# 2822             Juri         Yoshido
#
# [2823 rows x 2 columns]

# %% [markdown]
#  ### 9. Filtering Data (Conditional Selection)

# %%
df[df['SALES'] > 3079.44]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 7           10188               48     100.00                1  5512.32
# ...           ...              ...        ...              ...      ...
# 2793        10386               50      87.15               16  4357.50
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2       7/1/2003   Shipped       3         7     2003  ...
# 3      8/25/2003   Shipped       3         8     2003  ...
# 4     10/10/2003   Shipped       4        10     2003  ...
# 5     10/28/2003   Shipped       4        10     2003  ...
# 7     11/18/2003   Shipped       4        11     2003  ...
# ...          ...       ...     ...       ...      ...  ...
# 2793    3/1/2005  Resolved       1         3     2005  ...
# 2816  11/10/2004  Resolved       4        11     2004  ...
# 2817  11/21/2004   Shipped       4        11     2004  ...
# 2819   1/31/2005   Shipped       1         1     2005  ...
# 2820    3/1/2005  Resolved       1         3     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# 5                 9408 Furth Circle           NaN     Burlingame    CA
# 7       Drammen 121, PR 744 Sentrum           NaN         Bergen   NaN
# ...                             ...           ...            ...   ...
# 2793             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2816                   Vinb'ltet 34           NaN      Kobenhavn   NaN
# 2817               5905 Pompton St.     Suite 750            NYC    NY
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# 5         94217      USA       NaN          Hirano             Juri   Medium
# 7        N 5804   Norway      EMEA          Oeztan           Veysel   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2793      28034    Spain      EMEA          Freyre            Diego   Medium
# 2816       1734  Denmark      EMEA        Petersen            Jytte   Medium
# 2817      10022      USA       NaN       Hernandez            Maria   Medium
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
#
# [1485 rows x 25 columns]

# %% [markdown]
#  ### 10. Data Types of Columns

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
#  ### 11. Values of DataFrame

# %%
df.values
# Out:
# array([[10107, 30, 95.7, ..., 'Yu', 'Kwai', 'Small'],
#        [10121, 34, 81.35, ..., 'Henriot', 'Paul', 'Small'],
#        [10134, 41, 94.74, ..., 'Da Cunha', 'Daniel', 'Medium'],
#        ...,
#        [10386, 43, 100.0, ..., 'Freyre', 'Diego', 'Medium'],
#        [10397, 34, 62.24, ..., 'Roulet', 'Annette', 'Small'],
#        [10414, 47, 65.52, ..., 'Yoshido', 'Juri', 'Medium']], dtype=object)

# %% [markdown]
#  ### 12. Index Information

# %%
df.index
# RangeIndex(start=0, stop=n, step=1)
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %% [markdown]
# # 3.3 How to Read Data Files in Pandas (Common Parameters)
#  - Pandas provides the `read_csv()` function to read data from CSV files efficiently.
#  - It supports multiple parameters to handle different file formats and data issues.
#
# ---
#
#  ### Key Points
#  - `read_csv()` is highly flexible
#  - Helps clean and preprocess data while loading
#  - Commonly used in Data Analytics & EDA
#  - Do not use `names` when the file already has headers
#  - `parse_dates` is best used for date columns like ORDERDATE
#  - encoding="latin1" avoids UnicodeDecodeError
#  - Always verify data using `info()` after loading

# %% [markdown]
#  ### 1. Common Parameters in `read_csv()`
#  ### Explanation of Parameters
#  - sep → Defines the delimiter (`,` , `;` , `\t`)
#  - header → Row index containing column names
#  - names → Assign custom column names
#  - dtype → Specify data type for columns
#  - na_values → Symbols treated as missing values
#  - parse_dates → Automatically converts columns to date format

# %%
import pandas as pd

df = pd.read_csv(
    "Data/sales_data_sample.csv",
    encoding="latin1",              # Handle special characters
    sep=",",                        # Column separator
    header=0,                       # First row as column names
    na_values=["?", "NA", ""],      # Treat these as missing values
    parse_dates=["ORDERDATE"]       # Convert ORDERDATE to datetime
)

# %% [markdown]
#  ### 2. Converting Date Columns

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])

# %% [markdown]
#  ### 3. Example: Specifying Data Types

# %%
df = pd.read_csv(
    "Data/sales_data_sample.csv",
    encoding="latin1",
    dtype={
        "ORDERNUMBER": int,
        "QUANTITYORDERED": int,
        "PRICEEACH": float,
        "SALES": float,
        "YEAR_ID": int
    }
)

# %% [markdown]
#  ### 4. Renaming Columns (If Required)

# %%
df.columns = [
    "order_number", "quantity_ordered", "price_each", "order_line_number",
    "sales", "order_date", "status", "quarter_id", "month_id", "year_id",
    "product_line", "msrp", "product_code", "customer_name", "phone",
    "address1", "address2", "city", "state", "postal_code",
    "country", "territory", "contact_lastname", "contact_firstname",
    "deal_size"
]

# %% [markdown]
#  ### 5. Verifying the Data

# %%
df.head()
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_number       2823 non-null   int64
#  1   quantity_ordered   2823 non-null   int64
#  2   price_each         2823 non-null   float64
#  3   order_line_number  2823 non-null   int64
#  4   sales              2823 non-null   float64
#  5   order_date         2823 non-null   object
#  6   status             2823 non-null   object
#  7   quarter_id         2823 non-null   int64
#  8   month_id           2823 non-null   int64
#  9   year_id            2823 non-null   int64
#  10  product_line       2823 non-null   object
#  11  msrp               2823 non-null   int64
#  12  product_code       2823 non-null   object
#  13  customer_name      2823 non-null   object
#  14  phone              2823 non-null   object
#  15  address1           2823 non-null   object
#  16  address2           302 non-null    object
#  17  city               2823 non-null   object
#  18  state              1337 non-null   object
#  19  postal_code        2747 non-null   object
#  20  country            2823 non-null   object
#  21  territory          1749 non-null   object
#  22  contact_lastname   2823 non-null   object
#  23  contact_firstname  2823 non-null   object
#  24  deal_size          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB
# order_number           int64
# quantity_ordered       int64
# price_each           float64
# order_line_number      int64
# sales                float64
# order_date            object
# status                object
# quarter_id             int64
# month_id               int64
# year_id                int64
# product_line          object
# msrp                   int64
# product_code          object
# customer_name         object
# phone                 object
# address1              object
# address2              object
# city                  object
# state                 object
# postal_code           object
# country               object
# territory             object
# contact_lastname      object
# contact_firstname     object
# deal_size             object
# dtype: object

# %% [markdown]
# # 3.4 Exporting Pandas DataFrames
#
# Pandas provides multiple methods to **export DataFrames** to different file formats: CSV, Excel, JSON, etc.
#
# ---
#
# ### 1. Export to CSV
#  - `df.to_csv("output.csv", index=False)`
#  - `index=False` → Exclude row indices in the output file
#  - Saves the DataFrame as a CSV file
#
# ---
#
#  ### 2. Export to Excel
#  - `df.to_excel("output.xlsx", index=False)`
#  - Requires `openpyxl` or `xlsxwriter` library installed
#  - Saves DataFrame as an Excel file
#
# ---
#
#  ### 3. Export to JSON
#  - `df.to_json("output.json", orient="records")`
#  - orient="records" → Each row as a JSON object
#  - Can also use `orient="columns"` or `orient="index"`
#
# ---
#
#  #### Key Points
#  - Choose format based on use case
#  - Always set index=False if you don't want the index in output
#  - Useful for data sharing, reporting, and storage

# %% [markdown]
# # 3.5 Operations on Pandas DataFrame
# Pandas DataFrames support various operations like **selection, filtering, insertion, and deletion** of data.
#
# ---
#
#  #### Key Points
#  - **Selection** → `df['col']` or `df[['col1','col2']]`
#  - **Filtering** → Conditional selection using boolean indexing
#  - **Insertion** → `df['new_col']` = `[...]` or `df.insert()`
#  - **Deletion** → `drop()` or `del`
#  - Supports both row and column operations

# %% [markdown]
# ### 1. Selection

# %%
df = pd.read_csv(
    "Data/sales_data_sample.csv",
    encoding="latin1"
)
df['STATUS']        # Access single column
# Out:
# 0        Shipped
# 1        Shipped
# 2        Shipped
# 3        Shipped
# 4        Shipped
#           ...
# 2818     Shipped
# 2819     Shipped
# 2820    Resolved
# 2821     Shipped
# 2822     On Hold
# Name: STATUS, Length: 2823, dtype: object

# %% [markdown]
#  ### 2. Multiple Columns

# %%
df[['CONTACTFIRSTNAME', 'CONTACTLASTNAME']]
# Out:
#      CONTACTFIRSTNAME CONTACTLASTNAME
# 0                Kwai              Yu
# 1                Paul         Henriot
# 2              Daniel        Da Cunha
# 3               Julie           Young
# 4               Julie           Brown
# ...               ...             ...
# 2818            Diego          Freyre
# 2819           Pirkko       Koskitalo
# 2820            Diego          Freyre
# 2821          Annette          Roulet
# 2822             Juri         Yoshido
#
# [2823 rows x 2 columns]

# %% [markdown]
#  ### 3. Filtering

# %%
df[df['SALES'] > 3079.44]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 7           10188               48     100.00                1  5512.32
# ...           ...              ...        ...              ...      ...
# 2793        10386               50      87.15               16  4357.50
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2       7/1/2003   Shipped       3         7     2003  ...
# 3      8/25/2003   Shipped       3         8     2003  ...
# 4     10/10/2003   Shipped       4        10     2003  ...
# 5     10/28/2003   Shipped       4        10     2003  ...
# 7     11/18/2003   Shipped       4        11     2003  ...
# ...          ...       ...     ...       ...      ...  ...
# 2793    3/1/2005  Resolved       1         3     2005  ...
# 2816  11/10/2004  Resolved       4        11     2004  ...
# 2817  11/21/2004   Shipped       4        11     2004  ...
# 2819   1/31/2005   Shipped       1         1     2005  ...
# 2820    3/1/2005  Resolved       1         3     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# 5                 9408 Furth Circle           NaN     Burlingame    CA
# 7       Drammen 121, PR 744 Sentrum           NaN         Bergen   NaN
# ...                             ...           ...            ...   ...
# 2793             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2816                   Vinb'ltet 34           NaN      Kobenhavn   NaN
# 2817               5905 Pompton St.     Suite 750            NYC    NY
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# 5         94217      USA       NaN          Hirano             Juri   Medium
# 7        N 5804   Norway      EMEA          Oeztan           Veysel   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2793      28034    Spain      EMEA          Freyre            Diego   Medium
# 2816       1734  Denmark      EMEA        Petersen            Jytte   Medium
# 2817      10022      USA       NaN       Hernandez            Maria   Medium
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
#
# [1485 rows x 25 columns]

# %% [markdown]
#  ### 4. Insertion
# Adding a New Column
#
# ---
#
#  ### Tips:
#  - If the list length doesn’t match the DataFrame rows, it will raise an error.
#  - You can create dynamic columns using `apply()` or vectorized operations.

# %%
df = pd.DataFrame({
    'ORDERNUMBER': [10100, 10101, 10102],
    'QUANTITYORDERED': [30, 50, 22],
    'PRICEEACH': [100, 200, 150],
    'CUSTOMERNAME': ['John', 'Alice', 'Bob']
})

# 1️⃣ Adding a new column with a single default value
df['STATUS'] = 'Pending'

# 2️⃣ Adding a new column using a list of values
df['DISCOUNT'] = [0.1, 0.2, 0.15]  # Corresponds to each row

# 3️⃣ Adding a new column using a calculation
df['TOTALSALE'] = df['QUANTITYORDERED'] * df['PRICEEACH']

# Insert 'TAX' at 2nd position (index 1)
df.insert(1, 'TAX', [5, 10, 7])  # Example tax values per order

# Example: Adding a flag column based on sales
df['HIGH_VALUE'] = df['TOTALSALE'].apply(lambda x: 'Yes' if x > 5000 else 'No')

print(df)
# Out:
#    ORDERNUMBER  TAX  QUANTITYORDERED  PRICEEACH CUSTOMERNAME   STATUS  \
# 0        10100    5               30        100         John  Pending
# 1        10101   10               50        200        Alice  Pending
# 2        10102    7               22        150          Bob  Pending
#
#    DISCOUNT  TOTALSALE HIGH_VALUE
# 0      0.10       3000         No
# 1      0.20      10000        Yes
# 2      0.15       3300         No

# %% [markdown]
#  ### 5. Deletion in Pandas
# You can remove columns (or rows) from a DataFrame using either the drop() method or the del statement.
#
# ---
#
#  #### Tips:
#  - `drop()` is safer for multiple deletions and works well with row deletion `(axis=0)`.
#  - `del` is simpler for quick single-column removal.
#  - Always check your DataFrame after deletion to confirm changes.

# %% [markdown]
# #### Method 1: Using `drop()`
# The `drop()` method is flexible and widely used.

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'ORDERNUMBER': [10100, 10101, 10102],
    'QUANTITYORDERED': [30, 50, 22],
    'PRICEEACH': [100, 200, 150],
    'CUSTOMERNAME': ['John', 'Alice', 'Bob'],
    'TAX': [5, 10, 7]
})

# 1️⃣ Delete a single column
df1 = df.drop(columns=['TAX'])
print("After dropping TAX column:\n", df1)

# 2️⃣ Delete multiple columns
df2 = df.drop(columns=['PRICEEACH', 'QUANTITYORDERED'])
print("\nAfter dropping PRICEEACH and QUANTITYORDERED:\n", df2)

# Note: By default, drop() returns a new DataFrame. Use inplace=True to modify original.
# df.drop(columns=['TAX'], inplace=True)
# Out:
# After dropping TAX column:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH CUSTOMERNAME
# 0        10100               30        100         John
# 1        10101               50        200        Alice
# 2        10102               22        150          Bob
#
# After dropping PRICEEACH and QUANTITYORDERED:
#     ORDERNUMBER CUSTOMERNAME  TAX
# 0        10100         John    5
# 1        10101        Alice   10
# 2        10102          Bob    7

# %% [markdown]
#  #### Method 2: Using `del` Statement
# You can delete a column from the DataFrame in-place using `del`.

# %%
# Delete the TAX column
del df['TAX']

print("After deleting TAX column using del:\n", df)
# Out:
# After deleting TAX column using del:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH CUSTOMERNAME
# 0        10100               30        100         John
# 1        10101               50        200        Alice
# 2        10102               22        150          Bob

# %% [markdown]
#  ### 6. Using iloc for Row Deletion
#  #### Tips:
#  - `iloc` does not modify the original DataFrame; it returns a new DataFrame.
#  - For in-place deletion, you would use `drop(index=...)` instead.

# %%
# Sample DataFrame
df = pd.DataFrame({
    'ORDERNUMBER': [10100, 10101, 10102, 10103],
    'QUANTITYORDERED': [30, 50, 22, 15],
    'PRICEEACH': [100, 200, 150, 120],
    'CUSTOMERNAME': ['John', 'Alice', 'Bob', 'Mary']
})

# Suppose we want to delete the 2nd row (index 1)
df_new = df.iloc[[0, 2, 3]]  # Keep rows with index 0, 2, 3

print("After deleting row with index 1:\n", df_new)

# Delete rows with index 1 and 3
df_new = df.iloc[[0, 2]]  # Keep rows with index 0 and 2

print("\nAfter deleting rows with index 1 and 3:\n", df_new)
# Out:
# After deleting row with index 1:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH CUSTOMERNAME
# 0        10100               30        100         John
# 2        10102               22        150          Bob
# 3        10103               15        120         Mary
#
# After deleting rows with index 1 and 3:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH CUSTOMERNAME
# 0        10100               30        100         John
# 2        10102               22        150          Bob

# %% [markdown]
# ### 7. Renaming Columns

# %%
df = df.rename(columns={'PRICEEACH': 'price_each'})
print(df)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  price_each CUSTOMERNAME
# 0        10100               30         100         John
# 1        10101               50         200        Alice
# 2        10102               22         150          Bob
# 3        10103               15         120         Mary

# %% [markdown]
#  ### 8. Deleting a Particular Row

# %%
df = df.drop(2)   # Deletes the row with index 4

# %% [markdown]
#  ### 9. Adding a Particular Row
# You can add a row using loc (if index is known):

# %%
df.loc[4] = [10102, 40, 150, 'Pinki']
print(df)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  price_each CUSTOMERNAME
# 0        10100               30         100         John
# 1        10101               50         200        Alice
# 3        10103               15         120         Mary
# 4        10102               40         150        Pinki

# %% [markdown]
#  ### 10. Updating Values

# %%
# Update a single value
df.loc[2, 'PRICEEACH'] = 160  # Update Bob's PRICEEACH to 160

# Update multiple values
df.loc[[0, 2], 'CUSTOMERNAME'] = ['Jonathan', 'Robert']  # Update John → Jonathan, Bob → Robert

# update based on conditions:
# Update PRICEEACH where QUANTITYORDERED > 40
df.loc[df['QUANTITYORDERED'] > 40, 'PRICEEACH'] = 210

print(df)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  price_each CUSTOMERNAME  PRICEEACH
# 0      10100.0             30.0       100.0     Jonathan        NaN
# 1      10101.0             50.0       200.0        Alice      210.0
# 3      10103.0             15.0       120.0         Mary        NaN
# 4      10102.0             40.0       150.0        Pinki        NaN
# 2          NaN              NaN         NaN       Robert      160.0

# %% [markdown]
# # 3.6 Reading a Large CSV File in Chunks (Pandas)
#  - When working with **large CSV files**, loading the entire file into memory at once may be inefficient.
#  - Pandas provides the `chunksize` parameter to read data **in smaller chunks**.
#
# ---
#
#  #### Use Cases
#  - Handling large datasets
#  - Reducing memory usage
#  - Performing incremental processing (cleaning, filtering, aggregation)
#
# ---
#
#
# #### Key Points
#  - chunksize helps read files efficiently
#  - Each chunk is a DataFrame
#  - Use `pd.concat()` to merge chunks if needed

# %%
#chunksize=10 → Reads 10 rows at a time
#data becomes an iterator, not a DataFrame
data = pd.read_csv(
    "Data/sales_data_sample.csv",
    encoding="latin1",
    chunksize=10
)

# %% [markdown]
# ### Iterating Over Chunks
#  - Each chunk is a DataFrame
#  - Useful for processing large datasets step-by-step
#  - `ignore_index=True` → Resets index after concatenation
#  - Converts chunked data back into one DataFrame

# %%
chunks = []
for chunk in data:
    print(chunk)
    chunks.append(chunk)

df = pd.concat(chunks, ignore_index=True)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# 12        10251               28     100.00                2  3188.64
# 13        10263               34     100.00                2  3676.76
# 14        10275               45      92.83                1  4177.35
# 15        10285               36     100.00                6  4099.68
# 16        10299               23     100.00                9  2597.39
# 17        10309               41     100.00                5  4394.38
# 18        10318               46      94.74                1  4358.04
# 19        10329               42     100.00                1  4396.14
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10   2/20/2004  Shipped       1         2     2004  ...
# 11    4/5/2004  Shipped       2         4     2004  ...
# 12   5/18/2004  Shipped       2         5     2004  ...
# 13   6/28/2004  Shipped       2         6     2004  ...
# 14   7/23/2004  Shipped       3         7     2004  ...
# 15   8/27/2004  Shipped       3         8     2004  ...
# 16   9/30/2004  Shipped       3         9     2004  ...
# 17  10/15/2004  Shipped       4        10     2004  ...
# 18   11/2/2004  Shipped       4        11     2004  ...
# 19  11/15/2004  Shipped       4        11     2004  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2         CITY     STATE  \
# 10             636 St Kilda Road       Level 3    Melbourne  Victoria
# 11             2678 Kingston Rd.     Suite 101          NYC        NY
# 12                 7476 Moss Rd.           NaN       Newark        NJ
# 13           25593 South Bay Ln.           NaN  Bridgewater        CT
# 14  67, rue des Cinquante Otages           NaN       Nantes       NaN
# 15           39323 Spinnaker Dr.           NaN    Cambridge        MA
# 16                 Keskuskatu 45           NaN     Helsinki       NaN
# 17        Erling Skakkes gate 78           NaN      Stavern       NaN
# 18              7586 Pompton St.           NaN    Allentown        PA
# 19       897 Long Airport Avenue           NaN          NYC        NY
#
#    POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE
# 10       3004  Australia      APAC        Ferguson            Peter    Medium
# 11      10022        USA       NaN           Frick          Michael     Small
# 12      94019        USA       NaN           Brown          William    Medium
# 13      97562        USA       NaN            King            Julie    Medium
# 14      44000     France      EMEA         Labrune           Janine    Medium
# 15      51247        USA       NaN       Hernandez            Marta    Medium
# 16      21240    Finland      EMEA       Karttunen            Matti     Small
# 17       4110     Norway      EMEA      Bergulfsen            Jonas    Medium
# 18      70267        USA       NaN              Yu            Kyung    Medium
# 19      10022        USA       NaN              Yu             Kwai    Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 20        10341               41     100.00                9  7737.93
# 21        10361               20      72.55               13  1451.00
# 22        10375               21      34.91               12   733.11
# 23        10388               42      76.36                4  3207.12
# 24        10403               24     100.00                7  2434.56
# 25        10417               66     100.00                2  7516.08
# 26        10103               26     100.00               11  5404.62
# 27        10112               29     100.00                1  7209.11
# 28        10126               38     100.00               11  7329.06
# 29        10140               37     100.00               11  7374.10
#
#      ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 20  11/24/2004   Shipped       4        11     2004  ...
# 21  12/17/2004   Shipped       4        12     2004  ...
# 22    2/3/2005   Shipped       1         2     2005  ...
# 23    3/3/2005   Shipped       1         3     2005  ...
# 24    4/8/2005   Shipped       2         4     2005  ...
# 25   5/13/2005  Disputed       2         5     2005  ...
# 26   1/29/2003   Shipped       1         1     2003  ...
# 27   3/24/2003   Shipped       1         3     2003  ...
# 28   5/28/2003   Shipped       2         5     2003  ...
# 29   7/24/2003   Shipped       3         7     2003  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2         CITY STATE  \
# 20                              Geislweg 14           NaN     Salzburg   NaN
# 21  Monitor Money Building, 815 Pacific Hwy       Level 6    Chatswood   NSW
# 22             67, rue des Cinquante Otages           NaN       Nantes   NaN
# 23                        1785 First Street           NaN  New Bedford    MA
# 24             Berkeley Gardens 12  Brewery           NaN    Liverpool   NaN
# 25                       C/ Moralzarzal, 86           NaN       Madrid   NaN
# 26                   Erling Skakkes gate 78           NaN      Stavern   NaN
# 27                          Berguvsvgen  8           NaN         Lule   NaN
# 28                           C/ Araquil, 67           NaN       Madrid   NaN
# 29                        9408 Furth Circle           NaN   Burlingame    CA
#
#    POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 20       5020    Austria      EMEA           Pipps            Georg    Large
# 21       2067  Australia      APAC          Huxley           Adrian    Small
# 22      44000     France      EMEA         Labrune           Janine    Small
# 23      50553        USA       NaN         Benitez          Violeta   Medium
# 24    WX1 6LT         UK      EMEA           Devon        Elizabeth    Small
# 25      28034      Spain      EMEA          Freyre            Diego    Large
# 26       4110     Norway      EMEA      Bergulfsen            Jonas   Medium
# 27   S-958 22     Sweden      EMEA        Berglund        Christina    Large
# 28      28023      Spain      EMEA          Sommer           Mart¡n    Large
# 29      94217        USA       NaN          Hirano             Juri    Large
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 30        10150               45        100                8  10993.50
# 31        10163               21        100                1   4860.24
# 32        10174               34        100                4   8014.82
# 33        10183               23        100                8   5372.57
# 34        10194               42        100               11   7290.36
# 35        10206               47        100                6   9064.89
# 36        10215               35        100                3   6075.30
# 37        10228               29        100                2   6463.23
# 38        10245               34        100                9   6120.34
# 39        10258               32        100                6   7680.64
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 30   9/19/2003  Shipped       3         9     2003  ...
# 31  10/20/2003  Shipped       4        10     2003  ...
# 32   11/6/2003  Shipped       4        11     2003  ...
# 33  11/13/2003  Shipped       4        11     2003  ...
# 34  11/25/2003  Shipped       4        11     2003  ...
# 35   12/5/2003  Shipped       4        12     2003  ...
# 36   1/29/2004  Shipped       1         1     2004  ...
# 37   3/10/2004  Shipped       1         3     2004  ...
# 38    5/4/2004  Shipped       2         5     2004  ...
# 39   6/15/2004  Shipped       2         6     2004  ...
#
#                             ADDRESSLINE1  ADDRESSLINE2            CITY  \
# 30  Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN       Singapore
# 31                      5905 Pompton St.     Suite 750             NYC
# 32                31 Duncan St. West End           NaN  South Brisbane
# 33                      782 First Street           NaN    Philadelphia
# 34                    2, rue du Commerce           NaN            Lyon
# 35                          1900 Oak St.           NaN       Vancouver
# 36                     3675 Furth Circle           NaN         Burbank
# 37                        4658 Baden Av.           NaN       Cambridge
# 38              567 North Pendale Street           NaN       New Haven
# 39                        2-2-8 Roppongi           NaN       Minato-ku
#
#          STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME  \
# 30         NaN      79903  Singapore     Japan       Natividad
# 31          NY      10022        USA       NaN       Hernandez
# 32  Queensland       4101  Australia      APAC        Calaghan
# 33          PA      71270        USA       NaN       Cervantes
# 34         NaN      69004     France      EMEA         Saveley
# 35          BC    V3F 2K1     Canada       NaN       Tannamuri
# 36          CA      94019        USA       NaN        Thompson
# 37          MA      51247        USA       NaN           Tseng
# 38          CT      97823        USA       NaN          Murphy
# 39       Tokyo   106-0032      Japan     Japan       Shimamura
#
#    CONTACTFIRSTNAME DEALSIZE
# 30             Eric    Large
# 31            Maria   Medium
# 32             Tony    Large
# 33        Francisca   Medium
# 34             Mary    Large
# 35            Yoshi    Large
# 36            Steve   Medium
# 37            Kyung   Medium
# 38           Leslie   Medium
# 39            Akiko    Large
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 40        10270               21        100                9   4905.39
# 41        10280               34        100                2   8014.82
# 42        10291               37        100               11   7136.19
# 43        10304               47        100                6  10172.70
# 44        10312               48        100                3  11623.70
# 45        10322               40        100                1   6000.40
# 46        10333               26        100                3   3003.00
# 47        10347               30        100                1   3944.70
# 48        10357               32        100               10   5691.84
# 49        10369               41        100                2   4514.92
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 40   7/19/2004  Shipped       3         7     2004  ...
# 41   8/17/2004  Shipped       3         8     2004  ...
# 42    9/8/2004  Shipped       3         9     2004  ...
# 43  10/11/2004  Shipped       4        10     2004  ...
# 44  10/21/2004  Shipped       4        10     2004  ...
# 45   11/4/2004  Shipped       4        11     2004  ...
# 46  11/18/2004  Shipped       4        11     2004  ...
# 47  11/29/2004  Shipped       4        11     2004  ...
# 48  12/10/2004  Shipped       4        12     2004  ...
# 49   1/20/2005  Shipped       1         1     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2           CITY  \
# 40  Monitor Money Building, 815 Pacific Hwy       Level 6      Chatswood
# 41                      Via Monte Bianco 34           NaN         Torino
# 42                             ?kergatan 24           NaN          Boras
# 43                   67, avenue de l'Europe           NaN     Versailles
# 44                          5677 Strong St.           NaN     San Rafael
# 45                 2304 Long Airport Avenue           NaN         Nashua
# 46                5557 North Pendale Street           NaN  San Francisco
# 47                        636 St Kilda Road       Level 3      Melbourne
# 48                          5677 Strong St.           NaN     San Rafael
# 49                         7825 Douglas Av.           NaN     Brickhaven
#
#        STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 40       NSW       2067  Australia      APAC          Huxley           Adrian
# 41       NaN      10100      Italy      EMEA         Accorti            Paolo
# 42       NaN   S-844 67     Sweden      EMEA         Larsson            Maria
# 43       NaN      78000     France      EMEA          Tonini           Daniel
# 44        CA      97562        USA       NaN          Nelson          Valarie
# 45        NH      62005        USA       NaN           Young          Valarie
# 46        CA        NaN        USA       NaN          Murphy            Julie
# 47  Victoria       3004  Australia      APAC        Ferguson            Peter
# 48        CA      97562        USA       NaN          Nelson          Valarie
# 49        MA      58339        USA       NaN          Nelson            Allen
#
#    DEALSIZE
# 40   Medium
# 41    Large
# 42    Large
# 43    Large
# 44    Large
# 45   Medium
# 46   Medium
# 47   Medium
# 48   Medium
# 49   Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 50        10381               36     100.00                3   8254.80
# 51        10391               24     100.00                4   2416.56
# 52        10411               23     100.00                9   4140.23
# 53        10424               50     100.00                6  12001.00
# 54        10107               39      99.91                5   3896.49
# 55        10120               29      96.34                3   2793.86
# 56        10134               27     100.00                5   3307.77
# 57        10145               37     100.00                9   5192.95
# 58        10159               37     100.00               17   5016.83
# 59        10168               27     100.00                4   3660.93
#
#      ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 50   2/17/2005     Shipped       1         2     2005  ...
# 51    3/9/2005     Shipped       1         3     2005  ...
# 52    5/1/2005     Shipped       2         5     2005  ...
# 53   5/31/2005  In Process       2         5     2005  ...
# 54   2/24/2003     Shipped       1         2     2003  ...
# 55   4/29/2003     Shipped       2         4     2003  ...
# 56    7/1/2003     Shipped       3         7     2003  ...
# 57   8/25/2003     Shipped       3         8     2003  ...
# 58  10/10/2003     Shipped       4        10     2003  ...
# 59  10/28/2003     Shipped       4        10     2003  ...
#
#                      ADDRESSLINE1  ADDRESSLINE2           CITY     STATE  \
# 50                7734 Strong St.           NaN  San Francisco        CA
# 51              201 Miller Street      Level 15   North Sydney       NSW
# 52             43 rue St. Laurent           NaN       Montreal    Quebec
# 53             C/ Moralzarzal, 86           NaN         Madrid       NaN
# 54        897 Long Airport Avenue           NaN            NYC        NY
# 55              636 St Kilda Road       Level 3      Melbourne  Victoria
# 56  27 rue du Colonel Pierre Avia           NaN          Paris       NaN
# 57             78934 Hillside Dr.           NaN       Pasadena        CA
# 58                7734 Strong St.           NaN  San Francisco        CA
# 59              9408 Furth Circle           NaN     Burlingame        CA
#
#    POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 50        NaN        USA       NaN           Brown            Julie    Large
# 51       2060  Australia      APAC          O'Hara             Anna    Small
# 52    H1J 1C3     Canada       NaN       Fresnisre             Jean   Medium
# 53      28034      Spain      EMEA          Freyre            Diego    Large
# 54      10022        USA       NaN              Yu             Kwai   Medium
# 55       3004  Australia      APAC        Ferguson            Peter    Small
# 56      75508     France      EMEA        Da Cunha           Daniel   Medium
# 57      90003        USA       NaN           Young            Julie   Medium
# 58        NaN        USA       NaN           Brown            Julie   Medium
# 59      94217        USA       NaN          Hirano             Juri   Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 60        10180               42     100.00               12  4695.60
# 61        10188               38      96.34                4  3660.92
# 62        10201               24     100.00                5  3025.92
# 63        10210               23     100.00                2  3009.09
# 64        10223               47     100.00                4  5422.39
# 65        10236               22     100.00                1  2852.08
# 66        10251               44     100.00                5  5756.52
# 67        10263               40     100.00                5  4472.00
# 68        10275               22     100.00                4  2904.44
# 69        10285               47     100.00                9  6484.59
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 60  11/11/2003  Shipped       4        11     2003  ...
# 61  11/18/2003  Shipped       4        11     2003  ...
# 62   12/1/2003  Shipped       4        12     2003  ...
# 63   1/12/2004  Shipped       1         1     2004  ...
# 64   2/20/2004  Shipped       1         2     2004  ...
# 65    4/3/2004  Shipped       2         4     2004  ...
# 66   5/18/2004  Shipped       2         5     2004  ...
# 67   6/28/2004  Shipped       2         6     2004  ...
# 68   7/23/2004  Shipped       3         7     2004  ...
# 69   8/27/2004  Shipped       3         8     2004  ...
#
#                                 ADDRESSLINE1  ADDRESSLINE2           CITY  \
# 60                   184, chausse de Tournai           NaN          Lille
# 61               Drammen 121, PR 744 Sentrum           NaN         Bergen
# 62                 5557 North Pendale Street           NaN  San Francisco
# 63  Dojima Avanza 4F, 1-6-20 Dojima, Kita-ku           NaN          Osaka
# 64                         636 St Kilda Road       Level 3      Melbourne
# 65                         11328 Douglas Av.           NaN   Philadelphia
# 66                             7476 Moss Rd.           NaN         Newark
# 67                       25593 South Bay Ln.           NaN    Bridgewater
# 68              67, rue des Cinquante Otages           NaN         Nantes
# 69                       39323 Spinnaker Dr.           NaN      Cambridge
#
#        STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 60       NaN      59000     France      EMEA           Rance          Martine
# 61       NaN     N 5804     Norway      EMEA          Oeztan           Veysel
# 62        CA        NaN        USA       NaN          Murphy            Julie
# 63     Osaka   530-0003      Japan     Japan         Kentary             Mory
# 64  Victoria       3004  Australia      APAC        Ferguson            Peter
# 65        PA      71270        USA       NaN       Hernandez             Rosa
# 66        NJ      94019        USA       NaN           Brown          William
# 67        CT      97562        USA       NaN            King            Julie
# 68       NaN      44000     France      EMEA         Labrune           Janine
# 69        MA      51247        USA       NaN       Hernandez            Marta
#
#    DEALSIZE
# 60   Medium
# 61   Medium
# 62   Medium
# 63   Medium
# 64   Medium
# 65    Small
# 66   Medium
# 67   Medium
# 68    Small
# 69   Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 70        10298               39      96.34                1  3757.26
# 71        10308               34     100.00                2  4043.96
# 72        10318               45     100.00                4  5566.50
# 73        10329               20     100.00                2  3176.00
# 74        10339               40      68.92                4  2756.80
# 75        10361               26      51.15                8  1329.90
# 76        10374               39     100.00                5  5288.01
# 77        10388               50      44.51                5  2225.50
# 78        10402               45     100.00                1  5833.80
# 79        10417               45     100.00                5  5887.35
#
#      ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 70   9/27/2004   Shipped       3         9     2004  ...
# 71  10/15/2004   Shipped       4        10     2004  ...
# 72   11/2/2004   Shipped       4        11     2004  ...
# 73  11/15/2004   Shipped       4        11     2004  ...
# 74  11/23/2004   Shipped       4        11     2004  ...
# 75  12/17/2004   Shipped       4        12     2004  ...
# 76    2/2/2005   Shipped       1         2     2005  ...
# 77    3/3/2005   Shipped       1         3     2005  ...
# 78    4/7/2005   Shipped       2         4     2005  ...
# 79   5/13/2005  Disputed       2         5     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2            CITY  \
# 70                           54, rue Royale           NaN          Nantes
# 71                3758 North Pendale Street           NaN    White Plains
# 72                         7586 Pompton St.           NaN       Allentown
# 73                  897 Long Airport Avenue           NaN             NYC
# 74                           2-2-8 Roppongi           NaN       Minato-ku
# 75  Monitor Money Building, 815 Pacific Hwy       Level 6       Chatswood
# 76                   31 Duncan St. West End           NaN  South Brisbane
# 77                        1785 First Street           NaN     New Bedford
# 78                        25, rue Lauriston           NaN           Paris
# 79                       C/ Moralzarzal, 86           NaN          Madrid
#
#          STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME  \
# 70         NaN      44000     France      EMEA         Schmitt
# 71          NY      24067        USA       NaN           Frick
# 72          PA      70267        USA       NaN              Yu
# 73          NY      10022        USA       NaN              Yu
# 74       Tokyo   106-0032      Japan     Japan       Shimamura
# 75         NSW       2067  Australia      APAC          Huxley
# 76  Queensland       4101  Australia      APAC        Calaghan
# 77          MA      50553        USA       NaN         Benitez
# 78         NaN      75016     France      EMEA         Perrier
# 79         NaN      28034      Spain      EMEA          Freyre
#
#    CONTACTFIRSTNAME DEALSIZE
# 70           Carine   Medium
# 71            Steve   Medium
# 72            Kyung   Medium
# 73             Kwai   Medium
# 74            Akiko    Small
# 75           Adrian    Small
# 76             Tony   Medium
# 77          Violeta    Small
# 78        Dominique   Medium
# 79            Diego   Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 80        10107               27        100                4  6065.55
# 81        10120               46        100                2  9264.86
# 82        10134               31        100                4  7023.98
# 83        10145               33        100                8  5176.38
# 84        10159               22        100               16  4132.70
# 85        10168               20        100                3  4183.00
# 86        10180               41        100               11  8892.90
# 87        10188               45        100                3  8714.70
# 88        10201               49        100                4  8065.89
# 89        10210               34        100                1  6123.40
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 80   2/24/2003  Shipped       1         2     2003  ...
# 81   4/29/2003  Shipped       2         4     2003  ...
# 82    7/1/2003  Shipped       3         7     2003  ...
# 83   8/25/2003  Shipped       3         8     2003  ...
# 84  10/10/2003  Shipped       4        10     2003  ...
# 85  10/28/2003  Shipped       4        10     2003  ...
# 86  11/11/2003  Shipped       4        11     2003  ...
# 87  11/18/2003  Shipped       4        11     2003  ...
# 88   12/1/2003  Shipped       4        12     2003  ...
# 89   1/12/2004  Shipped       1         1     2004  ...
#
#                                 ADDRESSLINE1  ADDRESSLINE2           CITY  \
# 80                   897 Long Airport Avenue           NaN            NYC
# 81                         636 St Kilda Road       Level 3      Melbourne
# 82             27 rue du Colonel Pierre Avia           NaN          Paris
# 83                        78934 Hillside Dr.           NaN       Pasadena
# 84                           7734 Strong St.           NaN  San Francisco
# 85                         9408 Furth Circle           NaN     Burlingame
# 86                   184, chausse de Tournai           NaN          Lille
# 87               Drammen 121, PR 744 Sentrum           NaN         Bergen
# 88                 5557 North Pendale Street           NaN  San Francisco
# 89  Dojima Avanza 4F, 1-6-20 Dojima, Kita-ku           NaN          Osaka
#
#        STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 80        NY      10022        USA       NaN              Yu             Kwai
# 81  Victoria       3004  Australia      APAC        Ferguson            Peter
# 82       NaN      75508     France      EMEA        Da Cunha           Daniel
# 83        CA      90003        USA       NaN           Young            Julie
# 84        CA        NaN        USA       NaN           Brown            Julie
# 85        CA      94217        USA       NaN          Hirano             Juri
# 86       NaN      59000     France      EMEA           Rance          Martine
# 87       NaN     N 5804     Norway      EMEA          Oeztan           Veysel
# 88        CA        NaN        USA       NaN          Murphy            Julie
# 89     Osaka   530-0003      Japan     Japan         Kentary             Mory
#
#    DEALSIZE
# 80   Medium
# 81    Large
# 82    Large
# 83   Medium
# 84   Medium
# 85   Medium
# 86    Large
# 87    Large
# 88    Large
# 89   Medium
#
# [10 rows x 25 columns]
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 90        10223               49        100                3  9774.03
# 91        10237               39        100                9  7023.90
# 92        10251               43        100                4  7078.23
# 93        10263               41        100                4  8336.94
# 94        10275               36        100                3  6901.92
# 95        10285               27        100                8  5438.07
# 96        10299               29        100               11  6683.34
# 97        10308               20        100                1  4570.40
# 98        10318               37        100                3  7667.14
# 99        10329               26        100                3  5868.20
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 90   2/20/2004  Shipped       1         2     2004  ...
# 91    4/5/2004  Shipped       2         4     2004  ...
# 92   5/18/2004  Shipped       2         5     2004  ...
# 93   6/28/2004  Shipped       2         6     2004  ...
# 94   7/23/2004  Shipped       3         7     2004  ...
# 95   8/27/2004  Shipped       3         8     2004  ...
# 96   9/30/2004  Shipped       3         9     2004  ...
# 97  10/15/2004  Shipped       4        10     2004  ...
# 98   11/2/2004  Shipped       4        11     2004  ...
# 99  11/15/2004  Shipped       4        11     2004  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2          CITY     STATE  \
# 90             636 St Kilda Road       Level 3     Melbourne  Victoria
# 91             2678 Kingston Rd.     Suite 101           NYC        NY
# 92                 7476 Moss Rd.           NaN        Newark        NJ
# 93           25593 South Bay Ln.           NaN   Bridgewater        CT
# 94  67, rue des Cinquante Otages           NaN        Nantes       NaN
# 95           39323 Spinnaker Dr.           NaN     Cambridge        MA
# 96                 Keskuskatu 45           NaN      Helsinki       NaN
# 97     3758 North Pendale Street           NaN  White Plains        NY
# 98              7586 Pompton St.           NaN     Allentown        PA
# 99       897 Long Airport Avenue           NaN           NYC        NY
#
#    POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE
# 90       3004  Australia      APAC        Ferguson            Peter     Large
# 91      10022        USA       NaN           Frick          Michael     Large
# 92      94019        USA       NaN           Brown          William     Large
# 93      97562        USA       NaN            King            Julie     Large
# 94      44000     France      EMEA         Labrune           Janine    Medium
# 95      51247        USA       NaN       Hernandez            Marta    Medium
# 96      21240    Finland      EMEA       Karttunen            Matti    Medium
# 97      24067        USA       NaN           Frick            Steve    Medium
# 98      70267        USA       NaN              Yu            Kyung     Large
# 99      10022        USA       NaN              Yu             Kwai    Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 100        10339               39      76.67                3   2990.13
# 101        10362               22     100.00                4   3664.10
# 102        10374               22     100.00                1   3834.38
# 103        10388               21      86.77                7   1822.17
# 104        10403               66     100.00                9  11886.60
# 105        10417               56     100.00                4   9218.16
# 106        10105               50     100.00                2   7208.00
# 107        10119               46     100.00               11   5004.80
# 108        10129               33     100.00                2   4398.24
# 109        10143               49     100.00               15   5597.76
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 100  11/23/2004   Shipped       4        11     2004  ...
# 101    1/5/2005   Shipped       1         1     2005  ...
# 102    2/2/2005   Shipped       1         2     2005  ...
# 103    3/3/2005   Shipped       1         3     2005  ...
# 104    4/8/2005   Shipped       2         4     2005  ...
# 105   5/13/2005  Disputed       2         5     2005  ...
# 106   2/11/2003   Shipped       1         2     2003  ...
# 107   4/28/2003   Shipped       2         4     2003  ...
# 108   6/12/2003   Shipped       2         6     2003  ...
# 109   8/10/2003   Shipped       3         8     2003  ...
#
#                      ADDRESSLINE1  ADDRESSLINE2            CITY       STATE  \
# 100                2-2-8 Roppongi           NaN       Minato-ku       Tokyo
# 101             9408 Furth Circle           NaN      Burlingame          CA
# 102        31 Duncan St. West End           NaN  South Brisbane  Queensland
# 103             1785 First Street           NaN     New Bedford          MA
# 104  Berkeley Gardens 12  Brewery           NaN       Liverpool         NaN
# 105            C/ Moralzarzal, 86           NaN          Madrid         NaN
# 106                  Vinb'ltet 34           NaN       Kobenhavn         NaN
# 107                   Geislweg 14           NaN        Salzburg         NaN
# 108                35 King George           NaN          London         NaN
# 109             4575 Hillside Dr.           NaN     New Bedford          MA
#
#     POSTALCODE    COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 100   106-0032      Japan      Japan       Shimamura            Akiko    Small
# 101      94217        USA        NaN          Hirano             Juri   Medium
# 102       4101  Australia       APAC        Calaghan             Tony   Medium
# 103      50553        USA        NaN         Benitez          Violeta    Small
# 104    WX1 6LT         UK       EMEA           Devon        Elizabeth    Large
# 105      28034      Spain       EMEA          Freyre            Diego    Large
# 106       1734    Denmark       EMEA        Petersen            Jytte    Large
# 107       5020    Austria       EMEA           Pipps            Georg   Medium
# 108    WX3 6FW         UK       EMEA           Brown              Ann   Medium
# 109      50553        USA        NaN             Tam           Wing C   Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 110        10155               32        100               13  4526.08
# 111        10167               44        100                9  5924.16
# 112        10178               24        100               12  3492.48
# 113        10186               26        100                9  3854.24
# 114        10197               45        100                6  5324.40
# 115        10209               39        100                8  5197.92
# 116        10222               49        100               12  5997.60
# 117        10248               20        100                3  2910.40
# 118        10261               27        100                1  3378.24
# 119        10273               30        100                4  3508.80
#
#       ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 110   10/6/2003    Shipped       4        10     2003  ...
# 111  10/23/2003  Cancelled       4        10     2003  ...
# 112   11/8/2003    Shipped       4        11     2003  ...
# 113  11/14/2003    Shipped       4        11     2003  ...
# 114  11/26/2003    Shipped       4        11     2003  ...
# 115    1/9/2004    Shipped       1         1     2004  ...
# 116   2/19/2004    Shipped       1         2     2004  ...
# 117    5/7/2004  Cancelled       2         5     2004  ...
# 118   6/17/2004    Shipped       2         6     2004  ...
# 119   7/21/2004    Shipped       3         7     2004  ...
#
#                 ADDRESSLINE1  ADDRESSLINE2         CITY   STATE POSTALCODE  \
# 110            Keskuskatu 45           NaN     Helsinki     NaN      21240
# 111             ?kergatan 24           NaN        Boras     NaN   S-844 67
# 112    1 rue Alsace-Lorraine           NaN     Toulouse     NaN      31000
# 113          120 Hanover Sq.           NaN       London     NaN    WA1 1DP
# 114   Rambla de Catalu¤a, 23           NaN    Barcelona     NaN       8022
# 115         6047 Douglas Av.           NaN  Los Angeles      CA        NaN
# 116         361 Furth Circle           NaN    San Diego      CA      91217
# 117  897 Long Airport Avenue           NaN          NYC      NY      10022
# 118       43 rue St. Laurent           NaN     Montreal  Quebec    H1J 1C3
# 119      Rue Joseph-Bens 532           NaN    Bruxelles     NaN     B-1180
#
#      COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 110  Finland       EMEA       Karttunen            Matti   Medium
# 111   Sweden       EMEA         Larsson            Maria   Medium
# 112   France       EMEA          Roulet          Annette   Medium
# 113       UK       EMEA           Hardy           Thomas   Medium
# 114    Spain       EMEA        Saavedra          Eduardo   Medium
# 115      USA        NaN        Chandler          Michael   Medium
# 116      USA        NaN        Thompson          Valarie   Medium
# 117      USA        NaN              Yu             Kwai    Small
# 118   Canada        NaN       Fresnisre             Jean   Medium
# 119  Belgium       EMEA           Dewey        Catherine   Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 120        10283               25     100.00                6  2992.00
# 121        10295               24     100.00                1  3427.20
# 122        10307               22     100.00                9  2692.80
# 123        10316               33     100.00               17  4128.96
# 124        10325               47      64.93                6  3051.71
# 125        10337               25      48.05                8  1201.25
# 126        10350               26      75.47                5  1962.22
# 127        10359               48      54.68                6  2624.64
# 128        10373               39     100.00                3  4046.25
# 129        10384               34     100.00                4  4846.70
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 120   8/20/2004  Shipped       3         8     2004  ...
# 121   9/10/2004  Shipped       3         9     2004  ...
# 122  10/14/2004  Shipped       4        10     2004  ...
# 123   11/1/2004  Shipped       4        11     2004  ...
# 124   11/5/2004  Shipped       4        11     2004  ...
# 125  11/21/2004  Shipped       4        11     2004  ...
# 126   12/2/2004  Shipped       4        12     2004  ...
# 127  12/15/2004  Shipped       4        12     2004  ...
# 128   1/31/2005  Shipped       1         1     2005  ...
# 129   2/23/2005  Shipped       1         2     2005  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY          STATE  \
# 120         23 Tsawassen Blvd.           NaN      Tsawassen             BC
# 121         8616 Spinnaker Dr.           NaN         Boston             MA
# 122           782 First Street           NaN   Philadelphia             PA
# 123  Garden House Crowther Way           NaN          Cowes  Isle of Wight
# 124     Erling Skakkes gate 78           NaN        Stavern            NaN
# 125           5905 Pompton St.     Suite 750            NYC             NY
# 126         C/ Moralzarzal, 86           NaN         Madrid            NaN
# 127         59 rue de l'Abbaye           NaN          Reims            NaN
# 128                Torikatu 38           NaN           Oulu            NaN
# 129            7734 Strong St.           NaN  San Francisco             CA
#
#     POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 120    T2F 8M4   Canada       NaN         Lincoln        Elizabeth    Small
# 121      51003      USA       NaN         Yoshido             Juri   Medium
# 122      71270      USA       NaN       Cervantes        Francisca    Small
# 123   PO31 7PJ       UK      EMEA         Bennett            Helen   Medium
# 124       4110   Norway      EMEA      Bergulfsen            Jonas   Medium
# 125      10022      USA       NaN       Hernandez            Maria    Small
# 126      28034    Spain      EMEA          Freyre            Diego    Small
# 127      51100   France      EMEA         Henriot             Paul    Small
# 128      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 129        NaN      USA       NaN           Brown            Julie   Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 130        10395               32        100                2  3370.56
# 131        10400               64        100                9  9661.44
# 132        10414               19        100                3  2764.88
# 133        10103               42        100                4  5398.26
# 134        10114               31        100                8  4305.28
# 135        10126               22        100                4  3347.74
# 136        10140               26        100                4  3188.12
# 137        10150               20        100                1  3191.20
# 138        10164               21        100                2  3536.82
# 139        10175               33        100                9  5362.83
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 130   3/17/2005   Shipped       1         3     2005  ...
# 131    4/1/2005   Shipped       2         4     2005  ...
# 132    5/6/2005   On Hold       2         5     2005  ...
# 133   1/29/2003   Shipped       1         1     2003  ...
# 134    4/1/2003   Shipped       2         4     2003  ...
# 135   5/28/2003   Shipped       2         5     2003  ...
# 136   7/24/2003   Shipped       3         7     2003  ...
# 137   9/19/2003   Shipped       3         9     2003  ...
# 138  10/21/2003  Resolved       4        10     2003  ...
# 139   11/6/2003   Shipped       4        11     2003  ...
#
#                              ADDRESSLINE1  ADDRESSLINE2        CITY STATE  \
# 130         27 rue du Colonel Pierre Avia           NaN       Paris   NaN
# 131                        3086 Ingle Ln.           NaN    San Jose    CA
# 132                    8616 Spinnaker Dr.           NaN      Boston    MA
# 133                Erling Skakkes gate 78           NaN     Stavern   NaN
# 134               265, boulevard Charonne           NaN       Paris   NaN
# 135                        C/ Araquil, 67           NaN      Madrid   NaN
# 136                     9408 Furth Circle           NaN  Burlingame    CA
# 137  Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN   Singapore   NaN
# 138                          Kirchgasse 6           NaN        Graz   NaN
# 139                        35 King George           NaN      London   NaN
#
#     POSTALCODE    COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 130      75508     France       EMEA        Da Cunha           Daniel   Medium
# 131      94217        USA        NaN           Frick              Sue    Large
# 132      51003        USA        NaN         Yoshido             Juri    Small
# 133       4110     Norway       EMEA      Bergulfsen            Jonas   Medium
# 134      75012     France       EMEA        Bertrand            Marie   Medium
# 135      28023      Spain       EMEA          Sommer           Mart¡n   Medium
# 136      94217        USA        NaN          Hirano             Juri   Medium
# 137      79903  Singapore      Japan       Natividad             Eric   Medium
# 138       8010    Austria       EMEA          Mendel           Roland   Medium
# 139    WX3 6FW         UK       EMEA           Brown              Ann   Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 140        10183               28        100                1  3433.36
# 141        10194               26        100                4  4263.74
# 142        10207               31        100               15  4076.19
# 143        10217               48        100                4  7020.48
# 144        10229               50        100                9  6426.50
# 145        10245               28        100                2  4591.72
# 146        10259               26        100               12  4033.38
# 147        10270               32        100                2  4302.08
# 148        10281               44        100                9  7020.64
# 149        10291               30        100                4  3855.90
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 140  11/13/2003  Shipped       4        11     2003  ...
# 141  11/25/2003  Shipped       4        11     2003  ...
# 142   12/9/2003  Shipped       4        12     2003  ...
# 143    2/4/2004  Shipped       1         2     2004  ...
# 144   3/11/2004  Shipped       1         3     2004  ...
# 145    5/4/2004  Shipped       2         5     2004  ...
# 146   6/15/2004  Shipped       2         6     2004  ...
# 147   7/19/2004  Shipped       3         7     2004  ...
# 148   8/19/2004  Shipped       3         8     2004  ...
# 149    9/8/2004  Shipped       3         9     2004  ...
#
#                                 ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 140                         782 First Street           NaN  Philadelphia
# 141                       2, rue du Commerce           NaN          Lyon
# 142                           6251 Ingle Ln.           NaN        Boston
# 143  Village Close - 106 Linden Road Sandown     2nd Floor     Singapore
# 144                          5677 Strong St.           NaN    San Rafael
# 145                 567 North Pendale Street           NaN     New Haven
# 146  Village Close - 106 Linden Road Sandown     2nd Floor     Singapore
# 147  Monitor Money Building, 815 Pacific Hwy       Level 6     Chatswood
# 148                         7586 Pompton St.           NaN     Allentown
# 149                             ?kergatan 24           NaN         Boras
#
#     STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 140    PA      71270        USA       NaN       Cervantes        Francisca
# 141   NaN      69004     France      EMEA         Saveley             Mary
# 142    MA      51003        USA       NaN          Franco          Valarie
# 143   NaN      69045  Singapore      APAC       Victorino            Wendy
# 144    CA      97562        USA       NaN          Nelson          Valarie
# 145    CT      97823        USA       NaN          Murphy           Leslie
# 146   NaN      69045  Singapore      APAC       Victorino            Wendy
# 147   NSW       2067  Australia      APAC          Huxley           Adrian
# 148    PA      70267        USA       NaN              Yu            Kyung
# 149   NaN   S-844 67     Sweden      EMEA         Larsson            Maria
#
#     DEALSIZE
# 140   Medium
# 141   Medium
# 142   Medium
# 143    Large
# 144   Medium
# 145   Medium
# 146   Medium
# 147   Medium
# 148    Large
# 149   Medium
#
# [10 rows x 25 columns]
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 150        10305               38     100.00               13  6680.78
# 151        10313               40     100.00                7  6678.00
# 152        10322               46      61.99                8  2851.54
# 153        10334               26     100.00                2  3188.12
# 154        10347               27     100.00                2  4428.00
# 155        10357               43     100.00                9  5780.92
# 156        10370               35      65.63                4  2297.05
# 157        10381               37     100.00                6  6231.54
# 158        10391               37      46.90                7  1735.30
# 159        10411               27     100.00                2  4427.73
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 150  10/13/2004  Shipped       4        10     2004  ...
# 151  10/22/2004  Shipped       4        10     2004  ...
# 152   11/4/2004  Shipped       4        11     2004  ...
# 153  11/19/2004  On Hold       4        11     2004  ...
# 154  11/29/2004  Shipped       4        11     2004  ...
# 155  12/10/2004  Shipped       4        12     2004  ...
# 156   1/20/2005  Shipped       1         1     2005  ...
# 157   2/17/2005  Shipped       1         2     2005  ...
# 158    3/9/2005  Shipped       1         3     2005  ...
# 159    5/1/2005  Shipped       2         5     2005  ...
#
#                  ADDRESSLINE1  ADDRESSLINE2           CITY     STATE  \
# 150       39323 Spinnaker Dr.           NaN      Cambridge        MA
# 151              1900 Oak St.           NaN      Vancouver        BC
# 152  2304 Long Airport Avenue           NaN         Nashua        NH
# 153           Berguvsvgen  8           NaN           Lule       NaN
# 154         636 St Kilda Road       Level 3      Melbourne  Victoria
# 155           5677 Strong St.           NaN     San Rafael        CA
# 156         201 Miller Street      Level 15   North Sydney       NSW
# ...
# 2772         2440 Pompton St.           NaN     Glendale    CT      97561
# 2773        4575 Hillside Dr.           NaN  New Bedford    MA      50553
# 2774            Keskuskatu 45           NaN     Helsinki   NaN      21240
# 2775             ?kergatan 24           NaN        Boras   NaN   S-844 67
# 2776    1 rue Alsace-Lorraine           NaN     Toulouse   NaN      31000
# 2777          120 Hanover Sq.           NaN       London   NaN    WA1 1DP
# 2778   Rambla de Catalu¤a, 23           NaN    Barcelona   NaN       8022
# 2779         6047 Douglas Av.           NaN  Los Angeles    CA        NaN
#
#       COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2770    Italy       EMEA         Rovelli         Giovanni    Small
# 2771  Austria       EMEA           Pipps            Georg    Small
# 2772      USA        NaN           Lewis              Dan    Small
# 2773      USA        NaN             Tam           Wing C    Small
# 2774  Finland       EMEA       Karttunen            Matti    Small
# 2775   Sweden       EMEA         Larsson            Maria    Small
# 2776   France       EMEA          Roulet          Annette    Small
# 2777       UK       EMEA           Hardy           Thomas    Small
# 2778    Spain       EMEA        Saavedra          Eduardo    Small
# 2779      USA        NaN        Chandler          Michael    Small
#
# [10 rows x 25 columns]
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2780        10222               31      45.69                7  1416.39
# 2781        10249               32      57.61                3  1843.52
# 2782        10262               21      57.11               12  1199.31
# 2783        10274               32      58.60                4  1875.20
# 2784        10283               43      57.61                1  2477.23
# 2785        10296               21      45.19               10   948.99
# 2786        10307               34      53.63                4  1823.42
# 2787        10316               34      43.70               12  1485.80
# 2788        10329               44      86.13                8  3789.72
# 2789        10339               27      76.31                6  2060.37
#
#        ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2780   2/19/2004    Shipped       1         2     2004  ...
# 2781    5/8/2004    Shipped       2         5     2004  ...
# 2782   6/24/2004  Cancelled       2         6     2004  ...
# 2783   7/21/2004    Shipped       3         7     2004  ...
# 2784   8/20/2004    Shipped       3         8     2004  ...
# 2785   9/15/2004    Shipped       3         9     2004  ...
# 2786  10/14/2004    Shipped       4        10     2004  ...
# 2787   11/1/2004    Shipped       4        11     2004  ...
# 2788  11/15/2004    Shipped       4        11     2004  ...
# 2789  11/23/2004    Shipped       4        11     2004  ...
#
#                    ADDRESSLINE1  ADDRESSLINE2          CITY          STATE  \
# 2780           361 Furth Circle           NaN     San Diego             CA
# 2781             4658 Baden Av.           NaN     Cambridge             MA
# 2782         C/ Moralzarzal, 86           NaN        Madrid            NaN
# 2783           7825 Douglas Av.           NaN    Brickhaven             MA
# 2784         23 Tsawassen Blvd.           NaN     Tsawassen             BC
# 2785               Hansastr. 15           NaN        Munich            NaN
# 2786           782 First Street           NaN  Philadelphia             PA
# 2787  Garden House Crowther Way           NaN         Cowes  Isle of Wight
# 2788    897 Long Airport Avenue           NaN           NYC             NY
# 2789             2-2-8 Roppongi           NaN     Minato-ku          Tokyo
#
#      POSTALCODE  COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2780      91217      USA        NaN        Thompson          Valarie    Small
# 2781      51247      USA        NaN           Tseng            Kyung    Small
# 2782      28034    Spain       EMEA          Freyre            Diego    Small
# 2783      58339      USA        NaN          Nelson            Allen    Small
# 2784    T2F 8M4   Canada        NaN         Lincoln        Elizabeth    Small
# 2785      80686  Germany       EMEA     Donnermeyer          Michael    Small
# 2786      71270      USA        NaN       Cervantes        Francisca    Small
# 2787   PO31 7PJ       UK       EMEA         Bennett            Helen    Small
# 2788      10022      USA        NaN              Yu             Kwai   Medium
# 2789   106-0032    Japan      Japan       Shimamura            Akiko    Small
#
# [10 rows x 25 columns]
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2790        10352               49      52.64                4  2579.36
# 2791        10361               23      95.20               12  2189.60
# 2792        10373               25      64.97                9  1624.25
# 2793        10386               50      87.15               16  4357.50
# 2794        10398               34      40.22                1  1367.48
# 2795        10400               20      56.12                4  1122.40
# 2796        10415               42      57.61                3  2419.62
# 2797        10105               25      56.78                8  1419.50
# 2798        10117               50      43.68                2  2184.00
# 2799        10129               32      64.97                8  2079.04
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2790   12/3/2004   Shipped       4        12     2004  ...
# 2791  12/17/2004   Shipped       4        12     2004  ...
# 2792   1/31/2005   Shipped       1         1     2005  ...
# 2793    3/1/2005  Resolved       1         3     2005  ...
# 2794   3/30/2005   Shipped       1         3     2005  ...
# 2795    4/1/2005   Shipped       2         4     2005  ...
# 2796    5/9/2005  Disputed       2         5     2005  ...
# 2797   2/11/2003   Shipped       1         2     2003  ...
# 2798   4/16/2003   Shipped       2         4     2003  ...
# 2799   6/12/2003   Shipped       2         6     2003  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 2790                        16780 Pompton St.           NaN    Brickhaven
# 2791  Monitor Money Building, 815 Pacific Hwy       Level 6     Chatswood
# 2792                              Torikatu 38           NaN          Oulu
# 2793                       C/ Moralzarzal, 86           NaN        Madrid
# 2794                       59 rue de l'Abbaye           NaN         Reims
# 2795                           3086 Ingle Ln.           NaN      San Jose
# 2796                           7 Allen Street           NaN  Glen Waverly
# 2797                             Vinb'ltet 34           NaN     Kobenhavn
# 2798     Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN     Singapore
# 2799                           35 King George           NaN        London
#
#          STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME  \
# 2790        MA      58339        USA       NaN          Taylor
# 2791       NSW       2067  Australia      APAC          Huxley
# 2792       NaN      90110    Finland      EMEA       Koskitalo
# 2793       NaN      28034      Spain      EMEA          Freyre
# 2794       NaN      51100     France      EMEA         Henriot
# 2795        CA      94217        USA       NaN           Frick
# 2796  Victoria       3150  Australia      APAC         Connery
# 2797       NaN       1734    Denmark      EMEA        Petersen
# 2798       NaN      79903  Singapore     Japan       Natividad
# 2799       NaN    WX3 6FW         UK      EMEA           Brown
#
#      CONTACTFIRSTNAME DEALSIZE
# 2790           Leslie    Small
# 2791           Adrian    Small
# 2792           Pirkko    Small
# 2793            Diego   Medium
# 2794             Paul    Small
# 2795              Sue    Small
# 2796             Sean    Small
# 2797            Jytte    Small
# 2798             Eric    Small
# 2799              Ann    Small
#
# [10 rows x 25 columns]
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2800        10142               39      44.23                5  1724.97
# 2801        10153               50      60.06                4  3003.00
# 2802        10167               38      48.59               15  1846.42
# 2803        10177               40      50.23                6  2009.20
# 2804        10185               28      64.43                6  1804.04
# 2805        10197               42      50.23               12  2109.66
# 2806        10208               42      63.88                6  2682.96
# 2807        10222               36      63.34               18  2280.24
# 2808        10232               24      49.69                3  1192.56
# 2809        10248               23      65.52                9  1506.96
#
#        ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2800    8/8/2003    Shipped       3         8     2003  ...
# 2801   9/28/2003    Shipped       3         9     2003  ...
# 2802  10/23/2003  Cancelled       4        10     2003  ...
# 2803   11/7/2003    Shipped       4        11     2003  ...
# 2804  11/14/2003    Shipped       4        11     2003  ...
# 2805  11/26/2003    Shipped       4        11     2003  ...
# 2806    1/2/2004    Shipped       1         1     2004  ...
# 2807   2/19/2004    Shipped       1         2     2004  ...
# 2808   3/20/2004    Shipped       1         3     2004  ...
# 2809    5/7/2004  Cancelled       2         5     2004  ...
#
#                                 ADDRESSLINE1  ADDRESSLINE2         CITY  \
# 2800                         5677 Strong St.           NaN   San Rafael
# 2801                      C/ Moralzarzal, 86           NaN       Madrid
# 2802                            ?kergatan 24           NaN        Boras
# 2803  Merchants House, 27-30 Merchant's Quay           NaN       Madrid
# 2804                       4575 Hillside Dr.           NaN  New Bedford
# 2805                  Rambla de Catalu¤a, 23           NaN    Barcelona
# 2806                      2, rue du Commerce           NaN         Lyon
# 2807                        361 Furth Circle           NaN    San Diego
# 2808               Garden House Crowther Way           NaN        Cowes
# 2809                 897 Long Airport Avenue           NaN          NYC
#
#               STATE POSTALCODE COUNTRY  TERRITORY CONTACTLASTNAME  \
# 2800             CA      97562     USA        NaN          Nelson
# 2801            NaN      28034   Spain       EMEA          Freyre
# 2802            NaN   S-844 67  Sweden       EMEA         Larsson
# 2803            NaN      28023   Spain       EMEA       Fernandez
# 2804             MA      50553     USA        NaN             Tam
# 2805            NaN       8022   Spain       EMEA        Saavedra
# 2806            NaN      69004  France       EMEA         Saveley
# 2807             CA      91217     USA        NaN        Thompson
# 2808  Isle of Wight   PO31 7PJ      UK       EMEA         Bennett
# 2809             NY      10022     USA        NaN              Yu
#
#      CONTACTFIRSTNAME DEALSIZE
# 2800          Valarie    Small
# 2801            Diego   Medium
# 2802            Maria    Small
# 2803            Jesus    Small
# 2804           Wing C    Small
# 2805          Eduardo    Small
# 2806             Mary    Small
# 2807          Valarie    Small
# 2808            Helen    Small
# 2809             Kwai    Small
#
# [10 rows x 25 columns]
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2810        10261               29      50.78                7  1472.62
# 2811        10273               37      45.86               10  1696.82
# 2812        10283               33      51.32               12  1693.56
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2810   6/17/2004   Shipped       2         6     2004  ...
# 2811   7/21/2004   Shipped       3         7     2004  ...
# 2812   8/20/2004   Shipped       3         8     2004  ...
# 2813    9/9/2004   Shipped       3         9     2004  ...
# 2814  10/14/2004   Shipped       4        10     2004  ...
# 2815  10/29/2004   Shipped       4        10     2004  ...
# 2816  11/10/2004  Resolved       4        11     2004  ...
# 2817  11/21/2004   Shipped       4        11     2004  ...
# 2818   12/2/2004   Shipped       4        12     2004  ...
# 2819   1/31/2005   Shipped       1         1     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2        CITY   STATE  \
# 2810            43 rue St. Laurent           NaN    Montreal  Quebec
# 2811           Rue Joseph-Bens 532           NaN   Bruxelles     NaN
# 2812            23 Tsawassen Blvd.           NaN   Tsawassen      BC
# 2813           Via Monte Bianco 34           NaN      Torino     NaN
# 2814             Fauntleroy Circus           NaN  Manchester     NaN
# 2815  67, rue des Cinquante Otages           NaN      Nantes     NaN
# 2816                  Vinb'ltet 34           NaN   Kobenhavn     NaN
# 2817              5905 Pompton St.     Suite 750         NYC      NY
# 2818            C/ Moralzarzal, 86           NaN      Madrid     NaN
# 2819                   Torikatu 38           NaN        Oulu     NaN
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2810    H1J 1C3   Canada       NaN       Fresnisre             Jean    Small
# 2811     B-1180  Belgium      EMEA           Dewey        Catherine    Small
# 2812    T2F 8M4   Canada       NaN         Lincoln        Elizabeth    Small
# 2813      10100    Italy      EMEA         Accorti            Paolo    Small
# 2814    EC2 5NT       UK      EMEA        Ashworth         Victoria    Small
# 2815      44000   France      EMEA         Labrune           Janine    Small
# 2816       1734  Denmark      EMEA        Petersen            Jytte   Medium
# 2817      10022      USA       NaN       Hernandez            Maria   Medium
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
#
# [10 rows x 25 columns]
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2820   3/1/2005  Resolved       1         3     2005  ...
# 2821  3/28/2005   Shipped       1         3     2005  ...
# 2822   5/6/2005   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE COUNTRY  \
# 2820     C/ Moralzarzal, 86           NaN    Madrid   NaN      28034   Spain
# 2821  1 rue Alsace-Lorraine           NaN  Toulouse   NaN      31000  France
# 2822     8616 Spinnaker Dr.           NaN    Boston    MA      51003     USA
#
#       TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE
# 2820       EMEA          Freyre            Diego    Medium
# 2821       EMEA          Roulet          Annette     Small
# 2822        NaN         Yoshido             Juri    Medium
#
# [3 rows x 25 columns]

# %% [markdown]
# # 3.7. Handling Missing Values in Pandas
#  - Missing values in Pandas are usually represented as **NaN (Not a Number)**.
#  - Pandas provides powerful methods to **remove or replace missing data**.
#
# ---
#
#  #### Key Points
#  - `dropna()` → removes missing data
#  - `fillna()` → replaces missing data
#  - `ffill` / `bfill` useful for time-series data
#  - Use `inplace=True` to modify original DataFrame
#  - Always inspect missing values before handling

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": ["Amit", "Riya", None, "Pinki", None],
    "Age": [25, None, 30, None, 28],
    "City": ["Delhi", None, "Mumbai", None, None],
    "Score": [85, 90, None, None, None]
})

print(df)
# Out:
#     Name   Age    City  Score
# 0   Amit  25.0   Delhi   85.0
# 1   Riya   NaN    None   90.0
# 2   None  30.0  Mumbai    NaN
# 3  Pinki   NaN    None    NaN
# 4   None  28.0    None    NaN

# %% [markdown]
#  ### 1. `dropna()` – Remove Missing Values
#  - Drop Rows with Any Missing Value (Default)
#  - Drops the entire row if any column has NaN

# %%
df.dropna()
# Out:
#    Name   Age   City  Score
# 0  Amit  25.0  Delhi   85.0

# %% [markdown]
#  ### a). Drop Columns with Missing Values
#  ✔ Removes columns containing NaN

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
#  ### b). Drop Rows with Any Missing Value
#  ✔ Keeps row if at least one value exists

# %%
df.dropna(how="any")
# Out:
#    Name   Age   City  Score
# 0  Amit  25.0  Delhi   85.0

# %% [markdown]
#  ### c). Drop Rows Only If All Values Are Missing
#  ✔ Drops rows where Name is NaN

# %%
df.dropna(subset=["Name"])
# Out:
#     Name   Age   City  Score
# 0   Amit  25.0  Delhi   85.0
# 1   Riya   NaN   None   90.0
# 3  Pinki   NaN   None    NaN

# %% [markdown]
#  ### d). Drop Missing Values In-place
# ✔ Modifies original DataFrame

# %%
# df.dropna(inplace=True)

# %% [markdown]
#  ## e). Drop Rows with Minimum Non-NaN Values (thresh)
#  ✔ Keeps rows having at least 2 non-null values

# %%
df.dropna(thresh=2)
# Out:
#    Name   Age    City  Score
# 0  Amit  25.0   Delhi   85.0
# 1  Riya   NaN    None   90.0
# 2  None  30.0  Mumbai    NaN

# %% [markdown]
#  ### 2. `fillna()` – Fill Missing Values
# Fill All NaN with a Value

# %%
df.fillna(0)
# Out:
#     Name   Age    City  Score
# 0   Amit  25.0   Delhi   85.0
# 1   Riya   0.0       0   90.0
# 2      0  30.0  Mumbai    0.0
# 3  Pinki   0.0       0    0.0
# 4      0  28.0       0    0.0

# %% [markdown]
#  ### a). Fill with String Value

# %%
df.fillna("null")
# Out:
#     Name   Age    City Score
# 0   Amit  25.0   Delhi  85.0
# 1   Riya  null    null  90.0
# 2   null  30.0  Mumbai  null
# 3  Pinki  null    null  null
# 4   null  28.0    null  null

# %% [markdown]
# ### b). Fill Specific Column

# %%
df["City"].fillna("Unknown")
# Out:
# 0      Delhi
# 1    Unknown
# 2     Mumbai
# 3    Unknown
# 4    Unknown
# Name: City, dtype: object

# %% [markdown]
#  ### c). Forward Fill (ffill)
#  ✔ Fills NaN with previous value

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\chavi\AppData\Local\Temp\ipykernel_28284\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#     Name   Age    City  Score
# 0   Amit  25.0   Delhi   85.0
# 1   Riya  25.0   Delhi   90.0
# 2   Riya  30.0  Mumbai   90.0
# 3  Pinki  30.0  Mumbai   90.0
# 4  Pinki  28.0  Mumbai   90.0

# %% [markdown]
#  ### d). Backward Fill (bfill)
#  ✔ Fills NaN with next value

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\chavi\AppData\Local\Temp\ipykernel_28284\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#     Name   Age    City  Score
# 0   Amit  25.0   Delhi   85.0
# 1   Riya  30.0  Mumbai   90.0
# 2  Pinki  30.0  Mumbai    NaN
# 3  Pinki  28.0    None    NaN
# 4   None  28.0    None    NaN

# %% [markdown]
#  ### e). Fill In-place

# %%
 # df.fillna(0, inplace=True)

# %% [markdown]
#  ### f). Limit Filling
#  ✔ Fills only first 2 NaN values

# %%
df.fillna("null", limit=2)
# Out:
#     Name   Age    City Score
# 0   Amit  25.0   Delhi  85.0
# 1   Riya  null    null  90.0
# 2   null  30.0  Mumbai  null
# 3  Pinki  null    null  null
# 4   null  28.0    None   NaN

# %% [markdown]
# # 3.8 Aggregating Data in Pandas
#  - Aggregation in Pandas is used to **summarize data** using functions like sum, mean, min, max, etc.
#  - The most commonly used method is **`groupby()`**.
#
# ---
#
#  #### Key Points
#  - `groupby()` splits data into groups
#  - Aggregation functions summarize each group
#  - `agg()` allows multiple aggregations at once
#  - Common functions: `sum()`, `mean()`, `min()`, `max()`, `count()`

# %%
df = pd.DataFrame({
    "Name": ["Amit", "Amit", "Riya", "Riya", "Pinki", "Pinki"],
    "Dept": ["IT", "IT", "HR", "HR", "Sales", "Sales"],
    "Salary": [50000, 52000, 45000, 47000, 40000, 42000]
})

print(df)
# Out:
#     Name   Dept  Salary
# 0   Amit     IT   50000
# 1   Amit     IT   52000
# 2   Riya     HR   45000
# 3   Riya     HR   47000
# 4  Pinki  Sales   40000
# 5  Pinki  Sales   42000

# %% [markdown]
#  ### 1. GroupBy

# %%
grp = df.groupby("Name")
print(grp)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002056E15AEA0>

# %% [markdown]
#  ##### Iterating Through Groups

# %%
for x, y in grp:
    print(x)
    print(y)
# Out:
# Amit
#    Name Dept  Salary
# 0  Amit   IT   50000
# 1  Amit   IT   52000
# Pinki
#     Name   Dept  Salary
# 4  Pinki  Sales   40000
# 5  Pinki  Sales   42000
# Riya
#    Name Dept  Salary
# 2  Riya   HR   45000
# 3  Riya   HR   47000

# %% [markdown]
#  ### 2. Basic Aggregation Functions

# %%
#Sum
add = grp["Salary"].sum()
print(add)

#Mean
avg = grp["Salary"].mean()
print(avg)

#Max
maxi = grp["Salary"].max()
print(maxi)

#Min
mini = grp["Salary"].min()
print(mini)
# Out:
# Name
# Amit     102000
# Pinki     82000
# Riya      92000
# Name: Salary, dtype: int64
# Name
# Amit     51000.0
# Pinki    41000.0
# Riya     46000.0
# Name: Salary, dtype: float64
# Name
# Amit     52000
# Pinki    42000
# Riya     47000
# Name: Salary, dtype: int64
# Name
# Amit     50000
# Pinki    40000
# Riya     45000
# Name: Salary, dtype: int64

# %% [markdown]
# ### 3. Getting a Specific Group

# %%
grp.get_group("Amit")
# Out:
#    Name Dept  Salary
# 0  Amit   IT   50000
# 1  Amit   IT   52000

# %% [markdown]
#  ### 4. Aggregation on Entire DataFrame

# %%
print(df["Salary"].sum())
print(df["Salary"].mean())
print(df["Salary"].min())
print(df["Salary"].max())
# Out:
# 276000
# 46000.0
# 40000
# 52000

# %% [markdown]
#  ### 5. GroupBy with Column Selection
#   ###### Explanation
#  - Groups data by Dept
#  - Selects the Salary column
#  - Calculates mean salary for each department

# %%
df.groupby("Dept")["Salary"].mean()
# Out:
# Dept
# HR       46000.0
# IT       51000.0
# Sales    41000.0
# Name: Salary, dtype: float64

# %% [markdown]
#  ### 6. Multiple Aggregations Using `agg()`
#  #### Explanation
#  - Groups data by Dept
#  - Applies multiple aggregation functions on Salary

# %%
df.groupby("Dept").agg({
    "Salary": ["mean", "sum", "count"]
})
# Out:
#         Salary
#           mean     sum count
# Dept
# HR     46000.0   92000     2
# IT     51000.0  102000     2
# Sales  41000.0   82000     2

# %% [markdown]
# # 3.9 Melt (Reshaping Data)
# The `pandas.melt()` function is used to reshape a DataFrame from a wide format to a long format. It essentially "unpivots" columns into rows, making the data easier for analysis and visualization, especially when dealing with multiple columns that represent the same type of variable.
#  - melt() → Wide → Long format

# %%
df = pd.DataFrame({
    "Day": ["Mon", "Tue", "Wed"],
    "Sales_A": [100, 120, 130],
    "Sales_B": [90, 110, 140]
})

print(df)
# Out:
#    Day  Sales_A  Sales_B
# 0  Mon      100       90
# 1  Tue      120      110
# 2  Wed      130      140

# %% [markdown]
#  ### Melt Operation
# ✔ Converts wide format → long format

# %%
melted = pd.melt(
    df,
    id_vars=["Day"],
    value_vars=["Sales_A", "Sales_B"],
    var_name="Store",
    value_name="Sales"
)

print(melted)
# Out:
#    Day    Store  Sales
# 0  Mon  Sales_A    100
# 1  Tue  Sales_A    120
# 2  Wed  Sales_A    130
# 3  Mon  Sales_B     90
# 4  Tue  Sales_B    110
# 5  Wed  Sales_B    140

# %% [markdown]
#  # 3.10 Pivot (Reshaping Back)
#  In pandas, the `pivot()` function is used to reshape a DataFrame by transforming unique values from rows into columns, creating a "wide" data format. The more versatile `pivot_table()` function is a generalization that also allows for data aggregation and handles duplicate entries.
#  - `pivot()` → Long → Wide (no aggregation)
#  - `pivot_table()` → Allows aggregation

# %%
pivot_df = melted.pivot(
    index="Day",
    columns="Store",
    values="Sales"
)

print(pivot_df)
# Out:
# Store  Sales_A  Sales_B
# Day
# Mon        100       90
# Tue        120      110
# Wed        130      140

# %% [markdown]
#  ### Pivot with Another Example

# %%
df2 = pd.DataFrame({
    "student_name": ["Amit", "Amit", "Riya", "Riya"],
    "days": ["Mon", "Tue", "Mon", "Tue"],
    "marks": [80, 85, 90, 95]
})

pivot_marks = df2.pivot(
    index="days",
    columns="student_name",
    values="marks"
)

print(pivot_marks)
# Out:
# student_name  Amit  Riya
# days
# Mon             80    90
# Tue             85    95

# %% [markdown]
#  ### Pivot Table (Aggregation Allowed)

# %%
pivot_table = pd.pivot_table(
    df2,
    index="student_name",
    columns="days",
    values="marks",
    aggfunc="mean"
)

print(pivot_table)
# Out:
# days           Mon   Tue
# student_name
# Amit          80.0  85.0
# Riya          90.0  95.0

# %% [markdown]
#  # 3.11 Merge & Concat

# %%
df1 = pd.DataFrame({
    "A": [1, 2, 3],
    "B": [11, 12, 13]
})

df2 = pd.DataFrame({
    "A": [1, 2, 3, 4],
    "C": [21, 22, 23, 24]
})

# %% [markdown]
#  ### Merge
#  In pandas, `merge()` is used for database-style joining on common columns or indices.
#   - `merge()` → SQL-style joins

# %%
#Inner Merge (Default)
inn = pd.merge(df1, df2, on="A")
print("\nInner Merge\n", inn)

#Left Merge
lft = pd.merge(df1, df2, on="A", how="left")
print("\nLeft Merge\n", lft)

# Right Merge
rgt = pd.merge(df1, df2, on="A", how="right")
print("\nRight Merge\n", rgt)

# Outer Merge
ot = pd.merge(df1, df2, on="A", how="outer")
print("\nOuter Merge\n", ot)

# Outer Merge with Indicator
oti = pd.merge(df1, df2, on="A", how="outer", indicator=True)
print("\nOuter Merge with Indicator\n", oti)

# Merge Using Index
otIdx = pd.merge(df1, df2, left_index=True, right_index=True)
print("\nMerge Using Index\n", otIdx)

# Merge with Suffixes
suff = pd.merge(df1, df2, on="A", suffixes=("_left", "_right"))
print("\nMerge with Suffixes\n", suff)
# Out:
# Inner Merge
#     A   B   C
# 0  1  11  21
# 1  2  12  22
# 2  3  13  23
#
# Left Merge
#     A   B   C
# 0  1  11  21
# 1  2  12  22
# 2  3  13  23
#
# Right Merge
#     A     B   C
# 0  1  11.0  21
# 1  2  12.0  22
# 2  3  13.0  23
# 3  4   NaN  24
#
# Outer Merge
#     A     B   C
# 0  1  11.0  21
# 1  2  12.0  22
# 2  3  13.0  23
# 3  4   NaN  24
#
# Outer Merge with Indicator
#     A     B   C      _merge
# 0  1  11.0  21        both
# 1  2  12.0  22        both
# 2  3  13.0  23        both
# 3  4   NaN  24  right_only
#
# Merge Using Index
#     A_x   B  A_y   C
# 0    1  11    1  21
# 1    2  12    2  22
# 2    3  13    3  23
#
# Merge with Suffixes
#     A   B   C
# 0  1  11  21
# 1  2  12  22
# 2  3  13  23

# %% [markdown]
#  ### Concat Operations
#  `concat()` is used for stacking or appending DataFrames along an axis (rows or columns).
#   - `concat()` → Stack or combine data

# %%
# Series Concatenation
s1 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([11, 21, 31, 41])
sr = pd.concat([s1, s2])
print("\nSeries Concatenation\n", sr)

#DataFrame Row-wise Concat
rw = pd.concat([df1, df2])
print("\nDataFrame Row-wise Concat\n", rw)

#Column-wise Concat
cw = pd.concat([df1, df2], axis=1)
print("\nColumn-wise Concat\n", cw)

#Join Types in Concat
ot = pd.concat([df1, df2], join="outer")   # Union
print("\nOuter Join Concat\n", ot)

inn = pd.concat([df1, df2], join="inner")   # Intersection
print("\nInner Join Concat\n", inn)

#Using Keys
k = pd.concat([df1, df2], keys=["df1", "df2"])
print("\nUsing Keys\n", k)
# Out:
# Series Concatenation
#  0     1
# 1     2
# 2     3
# 3     4
# 0    11
# 1    21
# 2    31
# 3    41
# dtype: int64
#
# DataFrame Row-wise Concat
#     A     B     C
# 0  1  11.0   NaN
# 1  2  12.0   NaN
# 2  3  13.0   NaN
# 0  1   NaN  21.0
# 1  2   NaN  22.0
# 2  3   NaN  23.0
# 3  4   NaN  24.0
#
# Column-wise Concat
#       A     B  A   C
# 0  1.0  11.0  1  21
# 1  2.0  12.0  2  22
# 2  3.0  13.0  3  23
# 3  NaN   NaN  4  24
#
# Outer Join Concat
#     A     B     C
# 0  1  11.0   NaN
# 1  2  12.0   NaN
# 2  3  13.0   NaN
# 0  1   NaN  21.0
# 1  2   NaN  22.0
# 2  3   NaN  23.0
# 3  4   NaN  24.0
#
# Inner Join Concat
#     A
# 0  1
# 1  2
# 2  3
# 0  1
# 1  2
# 2  3
# 3  4
#
# Using Keys
#         A     B     C
# df1 0  1  11.0   NaN
#     1  2  12.0   NaN
#     2  3  13.0   NaN
# df2 0  1   NaN  21.0
#     1  2   NaN  22.0
#     2  3   NaN  23.0
#     3  4   NaN  24.0
